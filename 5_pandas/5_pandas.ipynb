# %% [markdown]
# # Pandas data manipulation

# %%
import pandas as pd

# %% [markdown]
# ## Import new dataset and explore it

# %%
cars = pd.read_csv('automobile_data.csv', sep=',', index_col=0)

# %%
cars
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0
# ...                ...         ...              ...      ...
# 81                four          85               27   7975.0
# 82                four          52               37   7995.0
# 86                four         100               26   9995.0
# 87                four         114               23  12940.0
# 88                four         114               23  13415.0
#
# [61 rows x 9 columns]

# %%
cars['company']
# Out:
# index
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
#          ...
# 81     volkswagen
# 82     volkswagen
# 86     volkswagen
# 87          volvo
# 88          volvo
# Name: company, Length: 61, dtype: object

# %%
cars['company'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mitsubishi',
#        'nissan', 'porsche', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
# Clean a bit the dataframe because the index are not continuous (61 rows, but index reach until 88)
cars.reset_index(inplace=True, drop=True)  
cars
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 0          111               21  13495.0
# 1          111               21  16500.0
# 2          154               19  16500.0
# 3          102               24  13950.0
# 4          115               18  17450.0
# ..         ...              ...      ...
# 56          85               27   7975.0
# 57          52               37   7995.0
# 58         100               26   9995.0
# 59         114               23  12940.0
# 60         114               23  13415.0
#
# [61 rows x 9 columns]

# %% [markdown]
# ## See first and last rows of the dataframe

# %%
cars.head(1)
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0

# %%
cars.tail(1)
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 60   volvo      wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 60         114               23  13415.0

# %% [markdown]
# ### First exercise: show the first five and the last 5 entries in the dataframe (in different commands)

# %% [markdown]
# ## Select rows based on row number

# %%
cars.iloc[1]
# Out:
# company             alfa-romero
# body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage              21
# price                     16500
# Name: 1, dtype: object

# %%
cars.iloc[1:3]
# Out:
#        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
#
#    horsepower  average-mileage    price
# 1         111               21  16500.0
# 2         154               19  16500.0

# %%
cars.iloc[[1,5,8,42]]
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 5          audi        sedan        99.8   177.3         ohc             five
# 8           bmw        sedan       101.2   176.8         ohc             four
# 42       nissan        sedan        94.5   165.3         ohc             four
#
#     horsepower  average-mileage    price
# 1          111               21  16500.0
# 5          110               19  15250.0
# 8          101               23  16925.0
# 42          69               31   6849.0

# %%
cars.iloc[[1,5,8,42]]['horsepower']  # even more "chopping"
# Out:
# 1     111
# 5     110
# 8     101
# 42     69
# Name: horsepower, dtype: int64

# %% [markdown]
# Do you miss **booleans** (True or False)? I miss booleans, let's do boleans. Let's find out which of the rows in the sublist of cars have the highest price.

# %%
subsection_cars = cars.iloc[[1,5,8,42]]
subsection_cars.price == subsection_cars['price'].max()
# Out:
# 1     False
# 5     False
# 8      True
# 42    False
# Name: price, dtype: bool

# %%
subsection_cars[subsection_cars.price == subsection_cars['price'].max()]
# Out:
#   company body-style  wheel-base  length engine-type num-of-cylinders  \
# 8     bmw      sedan       101.2   176.8         ohc             four
#
#    horsepower  average-mileage    price
# 8         101               23  16925.0

# %% [markdown]
# Let's select all the cars from the company bmw

# %%
cars[cars['company']=='bmw']
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 7      bmw      sedan       101.2   176.8         ohc             four
# 8      bmw      sedan       101.2   176.8         ohc             four
# 9      bmw      sedan       101.2   176.8         ohc              six
# 10     bmw      sedan       103.5   189.0         ohc              six
# 11     bmw      sedan       103.5   193.8         ohc              six
# 12     bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 7          101               23  16430.0
# 8          101               23  16925.0
# 9          121               21  20970.0
# 10         182               16  30760.0
# 11         182               16  41315.0
# 12         182               15  36880.0

# %% [markdown]
# Now all the cars with horsepower above 120

# %%
cars[cars['horsepower']>120]
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 2     alfa-romero    hatchback        94.5   171.2        ohcv
# 9             bmw        sedan       101.2   176.8         ohc
# 10            bmw        sedan       103.5   189.0         ohc
# 11            bmw        sedan       103.5   193.8         ohc
# 12            bmw        sedan       110.0   197.0         ohc
# 24         jaguar        sedan       113.0   199.6        dohc
# 25         jaguar        sedan       113.0   199.6        dohc
# 26         jaguar        sedan       102.0   191.7        ohcv
# 32  mercedes-benz        sedan       110.0   190.9         ohc
# 33  mercedes-benz        wagon       110.0   190.9         ohc
# 34  mercedes-benz        sedan       120.9   208.1        ohcv
# 35  mercedes-benz      hardtop       112.0   199.2        ohcv
# 44         nissan        sedan       100.4   184.6        ohcv
# 45        porsche      hardtop        89.5   168.9        ohcf
# 46        porsche  convertible        89.5   168.9        ohcf
# 47        porsche    hatchback        98.4   175.7       dohcv
# 54         toyota        wagon       104.5   187.8        dohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 2               six         154               19  16500.0
# 9               six         121               21  20970.0
# 10              six         182               16  30760.0
# 11              six         182               16  41315.0
# 12              six         182               15  36880.0
# 24              six         176               15  32250.0
# 25              six         176               15  35550.0
# 26           twelve         262               13  36000.0
# 32             five         123               22  25552.0
# 33             five         123               22  28248.0
# 34            eight         184               14  40960.0
# 35            eight         184               14  45400.0
# 44              six         152               19  13499.0
# 45              six         207               17  34028.0
# 46              six         207               17  37028.0
# 47            eight         288               17      NaN
# 54              six         156               19  15750.0

# %% [markdown]
# ### Second Exercise find the most expensive car in the whole cars dataframe

# %%
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
#
#     horsepower  average-mileage    price
# 35         184               14  45400.0

# %% [markdown]
# Now print only the name and the price

# %%
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# Let's count how many cars of each body-style are in the dataframe

# %%
cars['body-style'].value_counts()
# Out:
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: body-style, dtype: int64

# %% [markdown]
# ### Third exercise: Count how many cars of each company are present in the dataframe

# %%
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mercedes-benz    4
# mitsubishi       4
# audi             4
# volkswagen       4
# jaguar           3
# chevrolet        3
# isuzu            3
# porsche          3
# honda            3
# alfa-romero      3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %% [markdown]
# ## Data per company

# %%
car_companies = cars.groupby('company')  # This creates a pandas object that is not readable by itself
car_companies

# %% [markdown]
# We can see that we have an iterable object that has grouped all the entries based on the value that the column 'company' contains. We shouldn't use a for loop to operate with it, but we will use it now just to illustrate that all the data is there, just not visible for the moment.

# %%
for company in car_companies:
    print(company)
# Out:
# ('alfa-romero',        company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0  alfa-romero  convertible        88.6   168.8        dohc             four
# 1  alfa-romero  convertible        88.6   168.8        dohc             four
# 2  alfa-romero    hatchback        94.5   171.2        ohcv              six
#
#    horsepower  average-mileage    price
# 0         111               21  13495.0
# 1         111               21  16500.0
# 2         154               19  16500.0  )
# ('audi',   company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3    audi      sedan        99.8   176.6         ohc             four
# 4    audi      sedan        99.4   176.6         ohc             five
# 5    audi      sedan        99.8   177.3         ohc             five
# 6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3         102               24  13950.0
# 4         115               18  17450.0
# 5         110               19  15250.0
# 6         110               19  18920.0  )
# ('bmw',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 7      bmw      sedan       101.2   176.8         ohc             four
# 8      bmw      sedan       101.2   176.8         ohc             four
# 9      bmw      sedan       101.2   176.8         ohc              six
# 10     bmw      sedan       103.5   189.0         ohc              six
# 11     bmw      sedan       103.5   193.8         ohc              six
# 12     bmw      sedan       110.0   197.0         ohc              six
#
#     horsepower  average-mileage    price
# 7          101               23  16430.0
# 8          101               23  16925.0
# 9          121               21  20970.0
# 10         182               16  30760.0
# 11         182               16  41315.0
# 12         182               15  36880.0  )
# ('chevrolet',       company body-style  wheel-base  length engine-type num-of-cylinders  \
# 13  chevrolet  hatchback        88.4   141.1           l            three
# 14  chevrolet  hatchback        94.5   155.9         ohc             four
# 15  chevrolet      sedan        94.5   158.8         ohc             four
#
#     horsepower  average-mileage   price
# 13          48               47  5151.0
# 14          70               38  6295.0
# 15          70               38  6575.0  )
# ('dodge',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 16   dodge  hatchback        93.7   157.3         ohc             four
# 17   dodge  hatchback        93.7   157.3         ohc             four
#
#     horsepower  average-mileage   price
# 16          68               31  6377.0
# 17          68               31  6229.0  )
# ('honda',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 18   honda      wagon        96.5   157.1         ohc             four
# 19   honda      sedan        96.5   175.4         ohc             four
# 20   honda      sedan        96.5   169.1         ohc             four
#
#     horsepower  average-mileage    price
# 18          76               30   7295.0
# 19         101               24  12945.0
# 20         100               25  10345.0  )
# ('isuzu',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 21   isuzu      sedan        94.3   170.7         ohc             four
# 22   isuzu      sedan        94.5   155.9         ohc             four
# 23   isuzu      sedan        94.5   155.9         ohc             four
#
#     horsepower  average-mileage   price
# 21          78               24  6785.0
# 22          70               38     NaN
# 23          70               38     NaN  )
# ('jaguar',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 24  jaguar      sedan       113.0   199.6        dohc              six
# 25  jaguar      sedan       113.0   199.6        dohc              six
# 26  jaguar      sedan       102.0   191.7        ohcv           twelve
#
#     horsepower  average-mileage    price
# 24         176               15  32250.0
# 25         176               15  35550.0
# 26         262               13  36000.0  )
# ('mazda',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 27   mazda  hatchback        93.1   159.1         ohc             four
# 28   mazda  hatchback        93.1   159.1         ohc             four
# 29   mazda  hatchback        93.1   159.1         ohc             four
# 30   mazda  hatchback        95.3   169.0       rotor              two
# 31   mazda      sedan       104.9   175.0         ohc             four
#
#     horsepower  average-mileage    price
# 27          68               30   5195.0
# 28          68               31   6095.0
# 29          68               31   6795.0
# 30         101               17  11845.0
# 31          72               31  18344.0  )
# ('mercedes-benz',           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 32  mercedes-benz      sedan       110.0   190.9         ohc             five
# 33  mercedes-benz      wagon       110.0   190.9         ohc             five
# 34  mercedes-benz      sedan       120.9   208.1        ohcv            eight
# 35  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
#
#     horsepower  average-mileage    price
# 32         123               22  25552.0
# 33         123               22  28248.0
# 34         184               14  40960.0
# 35         184               14  45400.0  )
# ('mitsubishi',        company body-style  wheel-base  length engine-type num-of-cylinders  \
# 36  mitsubishi  hatchback        93.7   157.3         ohc             four
# 37  mitsubishi  hatchback        93.7   157.3         ohc             four
# 38  mitsubishi      sedan        96.3   172.4         ohc             four
# 39  mitsubishi      sedan        96.3   172.4         ohc             four
#
#     horsepower  average-mileage   price
# 36          68               37  5389.0
# 37          68               31  6189.0
# 38          88               25  6989.0
# 39          88               25  8189.0  )
# ('nissan',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 40  nissan      sedan        94.5   165.3         ohc             four
# 41  nissan      sedan        94.5   165.3         ohc             four
# 42  nissan      sedan        94.5   165.3         ohc             four
# 43  nissan      wagon        94.5   170.2         ohc             four
# 44  nissan      sedan       100.4   184.6        ohcv              six
#
#     horsepower  average-mileage    price
# 40          55               45   7099.0
# 41          69               31   6649.0
# 42          69               31   6849.0
# 43          69               31   7349.0
# 44         152               19  13499.0  )
# ('porsche',     company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 45  porsche      hardtop        89.5   168.9        ohcf              six
# 46  porsche  convertible        89.5   168.9        ohcf              six
# 47  porsche    hatchback        98.4   175.7       dohcv            eight
#
#     horsepower  average-mileage    price
# 45         207               17  34028.0
# 46         207               17  37028.0
# 47         288               17      NaN  )
# ('toyota',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48  toyota  hatchback        95.7   158.7         ohc             four
# 49  toyota  hatchback        95.7   158.7         ohc             four
# 50  toyota  hatchback        95.7   158.7         ohc             four
# 51  toyota      wagon        95.7   169.7         ohc             four
# 52  toyota      wagon        95.7   169.7         ohc             four
# 53  toyota      wagon        95.7   169.7         ohc             four
# 54  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0  )
# ('volkswagen',        company body-style  wheel-base  length engine-type num-of-cylinders  \
# 55  volkswagen      sedan        97.3   171.7         ohc             four
# 56  volkswagen      sedan        97.3   171.7         ohc             four
# 57  volkswagen      sedan        97.3   171.7         ohc             four
# 58  volkswagen      sedan        97.3   171.7         ohc             four
#
#     horsepower  average-mileage   price
# 55          52               37  7775.0
# 56          85               27  7975.0
# 57          52               37  7995.0
# 58         100               26  9995.0  )
# ('volvo',    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 59   volvo      sedan       104.3   188.8         ohc             four
# 60   volvo      wagon       104.3   188.8         ohc             four
#
#     horsepower  average-mileage    price
# 59         114               23  12940.0
# 60         114               23  13415.0  )

# %% [markdown]
# Now we want to know the maximum car price per company. To do that we'll use this grouped object and ask for its maximum values:

# %%
car_companies['price'].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
car_companies['price'].min()
# Out:
# company
# alfa-romero      13495.0
# audi             13950.0
# bmw              16430.0
# chevrolet         5151.0
# dodge             6229.0
# honda             7295.0
# isuzu             6785.0
# jaguar           32250.0
# mazda             5195.0
# mercedes-benz    25552.0
# mitsubishi        5389.0
# nissan            6649.0
# porsche          34028.0
# toyota            5348.0
# volkswagen        7775.0
# volvo            12940.0
# Name: price, dtype: float64

# %% [markdown]
# ### Fourth exercise: Put both the maximum and minimum horsepower of each brand in a dataframe with the columns 'max_hp' and 'min_hp' respectively. This can be done in one line if you feel like facing a challenge.

# %%
# Out:
#                    max      min
# company
# alfa-romero    16500.0  13495.0
# audi           18920.0  13950.0
# bmw            41315.0  16430.0
# chevrolet       6575.0   5151.0
# dodge           6377.0   6229.0
# honda          12945.0   7295.0
# isuzu           6785.0   6785.0
# jaguar         36000.0  32250.0
# mazda          18344.0   5195.0
# mercedes-benz  45400.0  25552.0
# mitsubishi      8189.0   5389.0
# nissan         13499.0   6649.0
# porsche        37028.0  34028.0
# toyota         15750.0   5348.0
# volkswagen      9995.0   7775.0
# volvo          13415.0  12940.0

# %% [markdown]
# ## Sort a dataframe based on the values of a column

# %% [markdown]
# Dataframes can be sorted according based on the data that it contains. Let's sort the cars dataframe based on their horsepower:

# %%
cars.sort_values(by='horsepower', ascending=True)
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 13      chevrolet    hatchback        88.4   141.1           l
# 55     volkswagen        sedan        97.3   171.7         ohc
# 57     volkswagen        sedan        97.3   171.7         ohc
# 40         nissan        sedan        94.5   165.3         ohc
# 49         toyota    hatchback        95.7   158.7         ohc
# ..            ...          ...         ...     ...         ...
# 34  mercedes-benz        sedan       120.9   208.1        ohcv
# 46        porsche  convertible        89.5   168.9        ohcf
# 45        porsche      hardtop        89.5   168.9        ohcf
# 26         jaguar        sedan       102.0   191.7        ohcv
# 47        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# 55             four          52               37   7775.0
# 57             four          52               37   7995.0
# 40             four          55               45   7099.0
# 49             four          62               31   6338.0
# ..              ...         ...              ...      ...
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 45              six         207               17  34028.0
# 26           twelve         262               13  36000.0
# 47            eight         288               17      NaN
#
# [61 rows x 9 columns]

# %% [markdown]
# ### Fifth exercise: sort the dataframe from more expensive to cheaper, then save it into a new variable and reset the index (dropping the original index).

# %%
expensive_to_cheap_cars = cars.sort_values(by='price', ascending=False)
expensive_to_cheap_cars.reset_index(inplace=True, drop = True)
expensive_to_cheap_cars
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 0   mercedes-benz      hardtop       112.0   199.2        ohcv
# 1             bmw        sedan       103.5   193.8         ohc
# 2   mercedes-benz        sedan       120.9   208.1        ohcv
# 3         porsche  convertible        89.5   168.9        ohcf
# 4             bmw        sedan       110.0   197.0         ohc
# ..            ...          ...         ...     ...         ...
# 56          mazda    hatchback        93.1   159.1         ohc
# 57      chevrolet    hatchback        88.4   141.1           l
# 58          isuzu        sedan        94.5   155.9         ohc
# 59          isuzu        sedan        94.5   155.9         ohc
# 60        porsche    hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0             eight         184               14  45400.0
# 1               six         182               16  41315.0
# 2             eight         184               14  40960.0
# 3               six         207               17  37028.0
# 4               six         182               15  36880.0
# ..              ...         ...              ...      ...
# 56             four          68               30   5195.0
# 57            three          48               47   5151.0
# 58             four          70               38      NaN
# 59             four          70               38      NaN
# 60            eight         288               17      NaN
#
# [61 rows x 9 columns]

# %% [markdown]
# ### Sixth exercise: Now remove all the rows for which the price is not a number (NaN)

# %% [markdown]
# Tip: check the `.notna()` function and remember how we normally subset dataframes. For reference, `isna()` does the opposite action.

# %%
expensive_to_cheap_cars[expensive_to_cheap_cars['price'].notna()]
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 0   mercedes-benz      hardtop       112.0   199.2        ohcv
# 1             bmw        sedan       103.5   193.8         ohc
# 2   mercedes-benz        sedan       120.9   208.1        ohcv
# 3         porsche  convertible        89.5   168.9        ohcf
# 4             bmw        sedan       110.0   197.0         ohc
# 5          jaguar        sedan       102.0   191.7        ohcv
# 6          jaguar        sedan       113.0   199.6        dohc
# 7         porsche      hardtop        89.5   168.9        ohcf
# 8          jaguar        sedan       113.0   199.6        dohc
# 9             bmw        sedan       103.5   189.0         ohc
# 10  mercedes-benz        wagon       110.0   190.9         ohc
# 11  mercedes-benz        sedan       110.0   190.9         ohc
# 12            bmw        sedan       101.2   176.8         ohc
# 13           audi        wagon       105.8   192.7         ohc
# 14          mazda        sedan       104.9   175.0         ohc
# 15           audi        sedan        99.4   176.6         ohc
# 16            bmw        sedan       101.2   176.8         ohc
# 17    alfa-romero    hatchback        94.5   171.2        ohcv
# 18    alfa-romero  convertible        88.6   168.8        dohc
# 19            bmw        sedan       101.2   176.8         ohc
# 20         toyota        wagon       104.5   187.8        dohc
# 21           audi        sedan        99.8   177.3         ohc
# 22           audi        sedan        99.8   176.6         ohc
# 23         nissan        sedan       100.4   184.6        ohcv
# 24    alfa-romero  convertible        88.6   168.8        dohc
# 25          volvo        wagon       104.3   188.8         ohc
# 26          honda        sedan        96.5   175.4         ohc
# 27          volvo        sedan       104.3   188.8         ohc
# 28          mazda    hatchback        95.3   169.0       rotor
# 29          honda        sedan        96.5   169.1         ohc
# 30     volkswagen        sedan        97.3   171.7         ohc
# 31         toyota        wagon        95.7   169.7         ohc
# 32     mitsubishi        sedan        96.3   172.4         ohc
# 33     volkswagen        sedan        97.3   171.7         ohc
# 34     volkswagen        sedan        97.3   171.7         ohc
# 35         toyota        wagon        95.7   169.7         ohc
# 36     volkswagen        sedan        97.3   171.7         ohc
# 37         nissan        wagon        94.5   170.2         ohc
# 38          honda        wagon        96.5   157.1         ohc
# 39         nissan        sedan        94.5   165.3         ohc
# 40     mitsubishi        sedan        96.3   172.4         ohc
# 41         toyota        wagon        95.7   169.7         ohc
# 42         nissan        sedan        94.5   165.3         ohc
# 43          mazda    hatchback        93.1   159.1         ohc
# 44          isuzu        sedan        94.3   170.7         ohc
# 45         nissan        sedan        94.5   165.3         ohc
# 46      chevrolet        sedan        94.5   158.8         ohc
# 47         toyota    hatchback        95.7   158.7         ohc
# 48          dodge    hatchback        93.7   157.3         ohc
# 49         toyota    hatchback        95.7   158.7         ohc
# 50      chevrolet    hatchback        94.5   155.9         ohc
# 51          dodge    hatchback        93.7   157.3         ohc
# 52     mitsubishi    hatchback        93.7   157.3         ohc
# 53          mazda    hatchback        93.1   159.1         ohc
# 54     mitsubishi    hatchback        93.7   157.3         ohc
# 55         toyota    hatchback        95.7   158.7         ohc
# 56          mazda    hatchback        93.1   159.1         ohc
# 57      chevrolet    hatchback        88.4   141.1           l
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0             eight         184               14  45400.0
# 1               six         182               16  41315.0
# 2             eight         184               14  40960.0
# 3               six         207               17  37028.0
# 4               six         182               15  36880.0
# 5            twelve         262               13  36000.0
# 6               six         176               15  35550.0
# 7               six         207               17  34028.0
# 8               six         176               15  32250.0
# 9               six         182               16  30760.0
# 10             five         123               22  28248.0
# 11             five         123               22  25552.0
# 12              six         121               21  20970.0
# 13             five         110               19  18920.0
# 14             four          72               31  18344.0
# 15             five         115               18  17450.0
# 16             four         101               23  16925.0
# 17              six         154               19  16500.0
# 18             four         111               21  16500.0
# 19             four         101               23  16430.0
# 20              six         156               19  15750.0
# 21             five         110               19  15250.0
# 22             four         102               24  13950.0
# 23              six         152               19  13499.0
# 24             four         111               21  13495.0
# 25             four         114               23  13415.0
# 26             four         101               24  12945.0
# 27             four         114               23  12940.0
# 28              two         101               17  11845.0
# 29             four         100               25  10345.0
# 30             four         100               26   9995.0
# 31             four          62               27   8778.0
# 32             four          88               25   8189.0
# 33             four          52               37   7995.0
# 34             four          85               27   7975.0
# 35             four          62               27   7898.0
# 36             four          52               37   7775.0
# 37             four          69               31   7349.0
# 38             four          76               30   7295.0
# 39             four          55               45   7099.0
# 40             four          88               25   6989.0
# 41             four          62               31   6918.0
# 42             four          69               31   6849.0
# 43             four          68               31   6795.0
# 44             four          78               24   6785.0
# 45             four          69               31   6649.0
# 46             four          70               38   6575.0
# 47             four          62               31   6488.0
# 48             four          68               31   6377.0
# 49             four          62               31   6338.0
# 50             four          70               38   6295.0
# 51             four          68               31   6229.0
# 52             four          68               31   6189.0
# 53             four          68               31   6095.0
# 54             four          68               37   5389.0
# 55             four          62               35   5348.0
# 56             four          68               30   5195.0
# 57            three          48               47   5151.0

# %% [markdown]
# ## Now let's add another entry to our original dataframe `cars`

# %%
new_entry = pd.DataFrame(data=[['opel', 'sedan', 100.0, 200.0, 'ohc', 'six', 100, 30, 25050.0]], columns = cars.columns)
new_entry
# Out:
#   company body-style  wheel-base  length engine-type num-of-cylinders  \
# 0    opel      sedan       100.0   200.0         ohc              six
#
#    horsepower  average-mileage    price
# 0         100               30  25050.0

# %%
cars_with_new_entries = pd.concat([cars, new_entry])
cars_with_new_entries
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
# 0          opel        sedan       100.0   200.0         ohc              six
#
#     horsepower  average-mileage    price
# 0          111               21  13495.0
# 1          111               21  16500.0
# 2          154               19  16500.0
# 3          102               24  13950.0
# 4          115               18  17450.0
# ..         ...              ...      ...
# 57          52               37   7995.0
# 58         100               26   9995.0
# 59         114               23  12940.0
# 60         114               23  13415.0
# 0          100               30  25050.0
#
# [62 rows x 9 columns]

# %% [markdown]
# ### Seventh exercise: concatenate the following dataframes that I provide bellow.

# %%
dfa = pd.DataFrame({'first_column':[1,2,3,4,5], 'second_colum':['A','B','C','D','E']})
dfa
# Out:
#    first_column second_colum
# 0             1            A
# 1             2            B
# 2             3            C
# 3             4            D
# 4             5            E

# %%
dfb = pd.DataFrame({'first_column':[6,7], 'second_colum':['F', 'G']})
dfb
# Out:
#    first_column second_colum
# 0             6            F
# 1             7            G

# %%
concat_df = pd.concat([dfa, dfb])
concat_df
# Out:
#    first_column second_colum
# 0             1            A
# 1             2            B
# 2             3            C
# 3             4            D
# 4             5            E
# 0             6            F
# 1             7            G

# %% [markdown]
# ## Merge dataframes

# %%
dfa = pd.DataFrame({'first_column':[1,2,3,4,5], 'second_colum':['A','B','C','D','E']})
dfa
# Out:
#    first_column second_colum
# 0             1            A
# 1             2            B
# 2             3            C
# 3             4            D
# 4             5            E

# %%
extra_info_df = pd.DataFrame({'first_column':[1,4,3,6], 'new_column': ['ham', 'eggs', 'spam', 'bacon']})
extra_info_df
# Out:
#    first_column new_column
# 0             1        ham
# 1             4       eggs
# 2             3       spam
# 3             6      bacon

# %%
merged_df = pd.merge(dfa,extra_info_df, on='first_column', how='left')  # Only keeps entries in dfa
merged_df
# Out:
#    first_column second_colum new_column
# 0             1            A        ham
# 1             2            B        NaN
# 2             3            C       spam
# 3             4            D       eggs
# 4             5            E        NaN

# %%
merged_df = pd.merge(dfa,extra_info_df, on='first_column', how='right')  # Only keeps entries in extra_info_df
merged_df
# Out:
#    first_column second_colum new_column
# 0             1            A        ham
# 1             3            C       spam
# 2             4            D       eggs
# 3             6          NaN      bacon

# %%
merged_df = pd.merge(dfa,extra_info_df, on='first_column', how='inner')  # Only keeps entries that appear both in dfa and extra_info_df
merged_df
# Out:
#    first_column second_colum new_column
# 0             1            A        ham
# 1             3            C       spam
# 2             4            D       eggs

# %%
merged_df = pd.merge(dfa,extra_info_df, on='first_column', how='outer')  # Keeps all the entries, it doesn't matter if it only appears on one of the dataframes
merged_df
# Out:
#    first_column second_colum new_column
# 0             1            A        ham
# 1             2            B        NaN
# 2             3            C       spam
# 3             4            D       eggs
# 4             5            E        NaN
# 5             6          NaN      bacon
